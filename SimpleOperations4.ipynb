# %% [markdown]
# <a href="https://colab.research.google.com/github/tanu-1906/Artificial_Intelligence_Lab_SE_B_13/blob/master/SimpleOperations4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = 19

# Convert the number to a string
num_str = str(number)

# Reverse the string
reversed_num_str = num_str[::-1]

# Check if the original and reversed strings are the same
if num_str == reversed_num_str:
    print(f"The number {number} is a palindrome.")
else:
    print(f"The number {number} is not a palindrome.")
# Out:
# The number 19 is not a palindrome.
