# %% [markdown]
# <a href="https://colab.research.google.com/github/tanu-1906/Artificial_Intelligence_Lab_SE_B_13/blob/master/SimpleOperations1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        res = 1
        for i in range(1, n + 1):
            res *= i
        return res

number = 6
result = factorial(number)
print(f"The factorial of {number} is {result}")
